# %%
import pandas as pd
import datetime
from dateutil import parser
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pytz
import requests
import json
import pprint
import os
import dateutil
import time
import re
import psycopg2
import pandas.io.sql as psql
from shutil import copyfile
import matplotlib.cm as cm

# %%
# historical data
import calendar

def next_weekday(d, weekday):
    days_ahead = weekday - d.weekday()
    if days_ahead < 0: # Target day already happened this week
        days_ahead += 7
    return d + datetime.timedelta(days_ahead)

# Given a start date and a match date in the future, get the next date (relative to the start date), 
# such that the next date is the same weekday and time as the match date
def next_weekday_matching_time(start_date, match_date):
    match_day = match_date.strftime("%A")
    next_date = next_weekday(start_date, list(calendar.day_name).index(match_day))
    return next_date.replace(hour=match_date.hour, minute=match_date.minute, second=match_date.second, microsecond=match_date.microsecond)

def bucketed(df, start_on="Sunday"):
    df = df.copy()
    df['created_at'] = pd.to_datetime(df['created_at']).dt.date
    min_date = df["created_at"].min()
    min_date = next_weekday(min_date, list(calendar.day_name).index(start_on))
    max_date = df["created_at"].max()
    tweet_counts = df.groupby('created_at').agg('count')["text"]
    dates = pd.date_range(min_date, max_date, freq='D')
    counts = pd.DataFrame({ "count": tweet_counts},index=dates).fillna(0)
    counts = counts.resample('7D').sum()
    return counts.drop(counts.tail(1).index) # drop last row in case its a count over less than the full time bucket

# %%
ACCOUNT_BALANCE = 58
N_TWEETS = 0

BEARER_TOKEN="AAAAAAAAAAAAAAAAAAAAAAXT9gAAAAAAoITLBCf%2B2K7BMSqakqcbsHUSLrk%3DLz95o8CkkhjOTthpcyEEg6BdNav0zphRcrEYdeG4GXXV3Qkftk"

## value functions
def expected_value(potential_win, chance_win, potential_loss, chance_loss):
    return (potential_win * chance_win) - (potential_loss * chance_loss)

def allocation(account_balance, expected_value):
    pct_alloc = min(( expected_value * 5 ) / 10, .03)
    alloc = account_balance * pct_alloc
    #risk_coef = 1 - (1 / (proba * 100) )
    #risk_adjusted = alloc * risk_coef
    #return risk_adjusted
    return alloc
def allocation(price_per_share, proba):
    payoff_odds = (1 / price_per_share) - 1

def recommended_shares(account_balance, expected_value, price_per_share):
    return allocation(account_balance, expected_value) / price_per_share;

def to_proba(buckets, categories=None):
    vals = buckets.value_counts()
    # [ (range(0,2), "0-2"), range(3-5), "3-5" ]
    #for c in categories:
    #    rnge = c[0]
    #    id_str = c[1]
    #    for r in range:
            
    s = vals.sum()
    return vals/s

## portfolio management
TAX_RATE = .1
def kelly_criterion(outcomes):
    # category, price_per_share, proba
    er = []
    betas = []
    for index, o in outcomes.iterrows():
        payoff_odds = (1 / o["price_per_share"]) - 1
        beta = 1 / (1 + payoff_odds)
        dividend_rate = 1 - TAX_RATE
        expected_revenue_rate = (dividend_rate / beta) * o["proba"]
        er.append(expected_revenue_rate)
        betas.append(beta)
        
    outcomes["expected_revenue_rate"] = er
    outcomes["beta"] = betas
    outcomes = outcomes.sort_values("expected_revenue_rate", ascending=False)
    
    reserve_rate = 1
    optimal_set = pd.DataFrame()
    for index, o in outcomes.iterrows():
        if o["expected_revenue_rate"] > reserve_rate:
            optimal_set = optimal_set.append(o)
            reserve_rate = (1 - optimal_set["proba"].sum()) / (1 - (optimal_set["beta"] / dividend_rate).sum())
        else:
            break
    
    pct_alloc = [] 
    for index, o in optimal_set.iterrows():
        pct = (o["expected_revenue_rate"] - reserve_rate) / ( dividend_rate / o["beta"] )
        pct_alloc.append(pct)
    optimal_set["pct_alloc"] = pct_alloc
    return optimal_set

def shares_bought(c, yes_or_no, positions):
    bought = 0
    if c in positions and yes_or_no in positions[c]:
        for pos in positions[c][yes_or_no]:
            bought += pos[1]
    return bought

def recommendation_buy(contract, yes_or_no, account_balance, expected_value, price_per_share, positions):
    shares = recommended_shares(account_balance, expected_value, price_per_share) - shares_bought(contract, yes_or_no, positions)
    shares = int(round(shares))
    if shares > 0:
        print("BUY {yn} shares for contract {n}: {shares} shares @{price} (EV: {ev}, TOTAL: {t})".format(n=contract,shares=shares, price=price_per_share, ev=expected_value, yn=yes_or_no.upper(), t=shares*price_per_share))

def recommendation_sell(contract, yes_or_no, expected_value, price_per_share, n_shares, bought_at):
    print("SELL {yn} shares for contract {n}_{bought_at}_{n_shares}: ALL shares @{price} (EV: {ev}, TOTAL: {t})".format(n=contract, price=price_per_share, ev=expected_value, yn=yes_or_no.upper(), t=n_shares*price_per_share, bought_at=bought_at, n_shares=n_shares))
    
## market evaluation
def fetch_market_data(market_id):
    url = "https://www.predictit.org/api/marketdata/markets/{id}".format(id=market_id)
    r = requests.get(url=url)
    return r.json()

# %%
def get_twitter_user_timeline(screen_name, max_id=None, since_id=None):
    url = "https://api.twitter.com/1.1/statuses/user_timeline.json"
    headers = { "Authorization": "Bearer {t}".format(t=BEARER_TOKEN)}
    params = {
        "count": "200",
        "trim_user": "true",
        "screen_name": screen_name
    }
    if max_id: 
        params["max_id"] = max_id
    if since_id:
        params["since_id"] = since_id
        
    r = requests.get(url=url,headers=headers, params=params)
    raw = r.json()
    transformed = json.dumps([ { "id": tweet["id"], "created_at": tweet["created_at"], "text": tweet["text"] } for tweet in raw])
    return pd.read_json(transformed, orient="records")

def get_recent_tweets(screen_name, from_date=None):
    df = get_twitter_user_timeline(screen_name)
    df["created_at"] = df["created_at"].dt.tz_localize('UTC').dt.tz_convert('US/Eastern')
    if from_date:
        df = df[df["created_at"] > from_date]
    return df
    
# the twitter api returns different results for the same request...
def _get_twitter_history(screen_name, max_id=None):
    get_next = True
    df = pd.DataFrame(columns=["id","created_at", "text"])
    while get_next:
        tweets = get_twitter_user_timeline(screen_name, max_id)
        print(len(tweets.index))
        if len(tweets.index) > 0:
            df = tweets if df.empty else pd.concat([df, tweets], axis=0)
            last_row = tweets.tail(1).iloc[0]
            max_id = last_row["id"] - 1
        else:
            get_next = False
    return df

# the twitter api returns different results for the same request...
def get_recent_twitter_history(screen_name, since_id):
    get_next = True
    df = pd.DataFrame(columns=["id","created_at", "text"])
    while get_next:
        tweets = get_twitter_user_timeline(screen_name, since_id=since_id)
        print(len(tweets.index))
        if len(tweets.index) > 0:
            df = tweets if df.empty else pd.concat([df, tweets], axis=0)
            most_recent = tweets.head(1).iloc[0] # TODO: prob should do better than this to ensure most recent
            since_id = most_recent["id"]
        else:
            get_next = False
    return df

# Gets all tweets before the earliest tweet stored locally for the given screen_name.
# If we have nothing stored locally for the screen_name, gets all tweets.
# NOTE: Twitter returns us most recent (n?) tweets, anything before that requires premium or enterprise account.
def get_twitter_history(screen_name, cache=True):
    fname = "data/tweets/{sn}.csv".format(sn=screen_name)
    max_id = None
    if cache and os.path.isfile(fname):
        df = pd.read_csv(fname)
        max_id = int(df.tail(1).iloc[0]["id"]) -1
    df = _get_twitter_history(screen_name, max_id);
    if not os.path.isdir("data/tweets"):
        os.mkdir("data/tweets")
    if len(df) > 0:
        df.to_csv(fname, mode='a', index=False, header=False)

# Gets all tweets after the latest tweet stored locally for the given screen_name.
# If we have nothing stored locally for the screen_name, gets all tweets.
def update_twitter_history(screen_name):
    fname = "data/tweets/{sn}.csv".format(sn=screen_name)
    if not os.path.isfile(fname):
        get_twitter_history(screen_name)
    else:
        # get since_id (most recent entry)
        # copy to .bak file
        # get most recent tweets starting at since_id
        # save df to file
        # copy old .bak to file
        copyfile(fname, fname + '.bak')
        
        df = pd.read_csv(fname)
        since_id = int(df.head(1).iloc[0]["id"])
                
        recent_tweets = get_recent_twitter_history(screen_name, since_id)
        if len(recent_tweets) > 0:
            recent_tweets.to_csv(fname, mode='w', index=False)
            historical_tweets = pd.read_csv(fname + '.bak')
            historical_tweets.to_csv(fname, mode='a', index=False, header=False)

def fetch_full_trump_tweet_history(rnge, cache=True):
    fname = "data/tweets/@realDonaldTrump.csv"
    df = None
    for year in rnge:
        url = None
        if year == 2019:
            url = "http://www.trumptwitterarchive.com/data/realdonaldtrump/2019.json"
        else:
            url = "http://d5nxcu7vtzvay.cloudfront.net/data/realdonaldtrump/{y}.json".format(y=str(year))
        _df  = pd.read_json(url)
        if df is None:
            df = _df
        else:
            df = pd.concat([df,_df])
        time.sleep(1)
     
    if not os.path.isdir("data/tweets"):
        os.mkdir("data/tweets")
    if len(df) > 0:
        df.to_csv(fname, mode='w')

# %% [markdown]
# #"homieng6@gmail.com"
# #"??"
# #"@homiesaccount"
# #"nY7VUVqcxJ4vmcX"
# #"AAAAAAAAAAAAAAAAAAAAAAXT9gAAAAAAoITLBCf%2B2K7BMSqakqcbsHUSLrk%3DLz95o8CkkhjOTthpcyEEg6BdNav0zphRcrEYdeG4GXXV3Qkft"

# %%
def show_twitter_market_research(csv_path):
    df = pd.read_csv(csv_path)
    df["created_at"] = pd.to_datetime(df['created_at']).dt.tz_localize('UTC').dt.tz_convert('US/Eastern')

    # number of tweets per week
    b=bucketed(df, start_on="Friday")
    b.plot(title="Tweets per Week")
    plt.show()
    
    tz = pytz.timezone("US/Eastern")
    start_date = tz.localize(datetime.datetime(2019,5,3,12,0,0)) # also Friday
    c = historical_tweet_counts(df, start_date, datetime.timedelta(0))
    c.plot(title="New Tweets per Week")
    plt.show()
    
    # distribution of tweets per week
    vals = b["count"].value_counts()
    bins = vals.size
    b["count"].plot(kind="hist",bins=bins, title="Tweets per Week Distribution")
    plt.show()
    
    # distribution of tweets per week
    vals = c.value_counts()
    bins = vals.size
    c.plot(kind="hist",bins=bins, title="New Tweets per Week Distribution")
    plt.show()
    
    # freq of tweets per day
    df['day_of_week'] = df["created_at"].dt.day_name()
    
    weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    df['day_of_week'].value_counts().reindex(weekdays).plot(kind='bar', title="Tweets per Calendar Day")
    plt.show()

# %%
def to_range_str(range):
    return str(range.start) + "-" + str(range.stop-1)

def append_count(series, count, category_range):
    return series.append(pd.Series([ count ], index=[ to_range_str(category_range) ]))

# takes dataframe with tweet counts bucketed per n days
# returns a data frame that returns counts for a category based, excluding coun
# this answers: what is the probability that we end in a category, given that we have already seen curr_n values
def count_adjusted(counts, categories, curr_n):
    grouped = pd.Series()
    for rnge in categories:
        adjusted_range = range(max(rnge.start-curr_n, 0), max(rnge.stop-curr_n, 0 ))
        count = len(counts[counts.between(adjusted_range.start, adjusted_range.stop-1)])
        grouped = append_count(grouped, count, rnge)
    return grouped

# %%
def market_start_date(end_date_str):
    end_date = parser.parse(end_date_str)
    return end_date - datetime.timedelta(days=7)

def time_boundaries(market_data, tz):
    contracts = market_data["contracts"]
    end_date_str = contracts[0]["dateEnd"]
    end_date = parser.parse(end_date_str)
    start_date = end_date - datetime.timedelta(days=7)
    return ( tz.localize(start_date), tz.localize(end_date) )
    
def eval_live_twitter_market(market, path, matching_tweets=None, show_market_research=False, dry_run=True):
    if show_market_research:
        show_twitter_market_research(path)
        
    market_data = fetch_market_data(market["id"])
    timezone = pytz.timezone("US/Eastern")
    utc_now = pytz.utc.localize(datetime.datetime.utcnow())
    ts = utc_now.astimezone(pytz.timezone("US/Eastern"))
    start_date, end_date = time_boundaries(market_data, timezone)
    
    matching_tweets = get_recent_tweets(market["twitter_handle"], from_date=start_date)
    if ( "filter" in market.keys() ):
        matching_tweets = matching_tweets[matching_tweets["text"].str.contains(market["filter"],case=False)]
        #n_matching_tweets = len(matching_tweets[matching_tweets["text"].str.contains("fake news|fakenews",case=False)])
    n_matching_tweets = len(matching_tweets)
    evaluation = eval_twitter_market(market, path, data=market_data, ts=ts, n_matching_tweets=n_matching_tweets, dry_run=dry_run)

    print(evaluation["name"])
    print("Days left:", evaluation["days_left"])
    print("Number of tweets:", evaluation["n_matching_tweets"])
    print("\nCategory probabilities:")
    print(evaluation["category_probabilities"])
    print("\nOptimal allocation:")
    print(evaluation["optimal_allocation"])
    print("\nNew Orders:")
    print(evaluation["orders"])

def eval_twitter_market(market, path, data=None, ts=None, n_matching_tweets=None, show_market_research=False, dry_run=True, tag=None, positions={}):
    if show_market_research:
        show_twitter_market_research(path)
        
    data["timezone"] = pytz.timezone("US/Eastern") # timeStamp field in market data seems to be in US/Eastern 
    contracts = data["contracts"]
    for c in contracts:
        c_id = str(c["id"])
        annotations = market["contract_map"][c_id]
        c["range"] = annotations["range"]
        c["category"] = to_range_str(c["range"])
    
    start_date, end_date = time_boundaries(data, data["timezone"])
    time_elapsed = ts - start_date
    
    # round to nearest day for old strategy
    time_elapsed = datetime.timedelta(days=round(time_elapsed.total_seconds() / (60*60*24)))
    
    df = pd.read_csv(path)
    df['created_at'] = pd.to_datetime(df["created_at"]).dt.tz_localize('UTC').dt.tz_convert('US/Eastern')
    bucketed = historical_tweet_counts(df, start_date, time_elapsed)
    c=count_adjusted(bucketed, [c["range"] for c in contracts], n_matching_tweets )
    proba = c/c.sum()
    
    category_stats = pd.DataFrame({ "price_per_share": [], "proba": [] })
    for c in contracts:
        s = pd.Series({ "price_per_share": c["bestBuyYesCost"], "proba": proba[c["category"]] })
        s.name = c["category"]
        category_stats = category_stats.append(s)
    alloc = kelly_criterion(category_stats)
    
    orders = place_orders(market["id"], contracts, alloc, ACCOUNT_BALANCE * .1, ts, positions, dry_run=dry_run, tag=tag)

    return {
        "name": data["shortName"],
        "days_left": (ts - start_date).total_seconds() / (60*60*24),
        "n_matching_tweets": n_matching_tweets,
        "category_probabilities": proba,
        "optimal_allocation": alloc,
        "orders": orders
    }
    #outcomes(positions, [c["category"] for c in contracts])

def days_left(end_date, ts):
    start_date = end_date - datetime.timedelta(days=7)
    delta = ts - start_date
    days_left = ((7*24) - (delta.total_seconds()/3600))/24
    return max(round(days_left),1)
                    
def outcomes(positions, categories):
    for c in categories:
        total = 0
        for pp in positions:
            if pp == c:
                if "yes" in positions[pp]:
                    for x in positions[pp]["yes"]:
                        total += (1 - x[0])*x[1]
                if "no" in positions[pp]:
                    for x in positions[pp]["no"]:
                        total -= x[0]*x[1]
            else:
                if "yes" in positions[pp]:
                    for x in positions[pp]["yes"]:
                        total -= x[0]*x[1]
                if "no" in positions[pp]:
                    for x in positions[pp]["no"]:
                        total += (1-x[0])*x[1]
        print(c, total)

# %%
# scale EV by risk for final quantity recommendations (to reduce volatility)
# take expected tweets for day of week into account given some people dont tweet much on weekends
# graph of tweet density per time per day

# %%
markets = [
    { 
        "id": 5505, 
        "twitter_handle": "@vp", 
        "contract_map": {
            "15496": { "range": range(0, 40) }, 
            "15502": { "range": range(40, 45) },
            "15500": { "range": range(45, 50) },
            "15499": { "range": range(50, 55) },
            "15497": { "range": range(55, 60) },
            "15501": { "range": range(60, 65) },
            "15498": { "range": range(65, 120) }
        },
        "positions":{ 
        }
    },
    { 
        "id": 5504, 
        "twitter_handle": "@potus", 
        "contract_map": {
            "15489": { "range": range(0, 55) },
            "15490": { "range": range(55, 60) }, 
            "15491": { "range": range(60, 65) }, 
            "15492": { "range": range(65, 70) },
            "15494": { "range": range(70, 75) }, 
            "15493": { "range": range(75, 80) },
            "15495": { "range": range(80, 200) }
        },
        "positions": {
        }
    }
]
_markets = [
    { 
        "id": 5478, 
        "twitter_handle": "@vp", 
        "contract_map": {
            "15348": { "range": range(0, 30) }, 
            "15353": { "range": range(30, 35) }, 
            "15349": { "range": range(35, 40) }, 
            "15354": { "range": range(40, 45) },
            "15352": { "range": range(45, 50) },
            "15351": { "range": range(50, 55) },
            "15350": { "range": range(55, 100) }
        },
        "positions":{ 
        }
    },
    { 
        "id": 5407, 
        "twitter_handle": "@whitehouse", 
        "contract_map": {
            "14983": { "range": range(0, 80) }, 
            "14985": { "range": range(80, 85) }, 
            "14984": { "range": range(85, 90) },
            "14986": { "range": range(90, 95) },
            "14987": { "range": range(95, 100) },
            "14988": { "range": range(100, 105) }, 
            "14989": { "range": range(105, 300) }
        },
        #"contract_map": [ ("14983", range(0, 80)), ("14985",range(80, 85)), ("14984", range(85, 90)), ("14986", range(90, 95)), ("14987",range(95, 100)), ("14988", range(100, 105)), ("14989",range(105, 300))],
        "positions": { 
        }
    },
    #{
    #    "id": 5404, 
    #    "twitter_handle": "@realDonaldTrump",
    #    "contract_map": {
    #        "14968": { "range": range(0, 60) }, 
    #        "14963": { "range": range(60, 65) }, 
    #        "14967": { "range": range(65, 70) },
    #        "14965": { "range": range(70, 75) },
    #        "14964": { "range": range(75, 80) },
    #        "14966": { "range": range(80, 85) }, 
    #        "14962": { "range": range(85, 200) }
    #    },
    #    #"contract_map": [ ("14968", range(0, 60)), ("14963",range(60, 65)), ("14967", range(65, 70)), ("14965", range(70, 75)), ("14964",range(75, 80)), ("14966", range(80, 85)), ("14962",range(85, 200))],
    #    "positions": {
            #"0-59": {
            #    "yes": [(.12, 11)]
            #},
            #"60-64": {
            #    "yes": [(.11, 12)]
            #},
            #"70-74": {
            #    "yes": [(.04, 20)]
            #},
            #"80-84": {
            #    "no": [(.69, 4)]
            #},
            #"85-199": {
            #    "no": [(.74, 4),(.64,1),(.54,1), (.34, 3)]
            #}
     #   }
    #},
    { 
        "id": 5479, 
        "twitter_handle": "@potus", 
        "contract_map": {
            "15355": { "range": range(0, 45) }, 
            "15359": { "range": range(45, 50) },
            "15360": { "range": range(50, 55) },
            "15356": { "range": range(55, 60) }, 
            "15357": { "range": range(60, 65) }, 
            "15358": { "range": range(65, 69) },
            "15361": { "range": range(70, 200) }
        },
        "positions": {
        }
    }
]

def eval_live_markets(show_market_research=False, dry_run=True):
    for market in markets:
        eval_live_twitter_market(
            market,
            "data/tweets/{handle}.csv".format(handle=market["twitter_handle"]),
            show_market_research=show_market_research,
            dry_run=dry_run
        )
        print("----------------------------------------\n\n")

# %%
# 1 pct = .005
# 2 pct = .01
# 4 pct = .02
# 8 pct = .03
def alloc(expected_value, proba): 
    pct_alloc = min( expected_value / 2, .03)
    risk_adjusted = pct_alloc# * ??
    return risk_adjusted

# %%
def append_order(_order, orders_df, ts):
    order = pd.Series(_order)
    order.name = ts
    row = order.to_frame().transpose()
    orders_df = orders_df.append(row)
    if len(orders_df) == 1:
        orders_df.index.name = "timestamp"
    return orders_df
        
def place_orders(market_id, contracts, optimal_set, account_balance, ts, positions, dry_run=True, tag=None):
    orders_df = pd.DataFrame()
    for contract in contracts:
        category = contract["category"]
        price_per_share = contract["bestBuyYesCost"]
        current_quantity = positions[contract["id"]][0] if contract["id"] in positions else 0
#        current_quantity = current_alloc(market_id, contract["id"], tag=tag)
        
        if category not in optimal_set.index:
            # TODO: this doesnt take into consideration sell price, which in this market is usually less than buy price
            # could sell at best buy price...
            if current_quantity > 0:
                _order = {
                    "action": "sell",
                    "category": category,
                    "type": "yes", 
                    "price_per_share": price_per_share,
                    "quantity": current_quantity,
                    "market_id": market_id,
                    "contract_id": contract["id"]
                }
                orders_df = append_order(_order, orders_df, ts)
                if not dry_run:
                    place_order(_order, tag=tag)
                    
        else:
            row = optimal_set.loc[category,:]
            optimal_alloc = (row["pct_alloc"] * account_balance)
            optimal_quantity = round( abs(optimal_alloc / price_per_share) )
            quantity = optimal_quantity - current_quantity
            if quantity == 0:
                break
            
            # debug stuff
            #print("buy quantity:", quantity, "at price:", price_per_share)
            
            action = "sell" if quantity < 0 else "buy"
            _order = {
                "action": action, 
                "category": category,
                "type": "yes", 
                "price_per_share": price_per_share,
                "quantity": abs(quantity),
                "market_id": market_id,
                "contract_id": contract["id"]
            }
            orders_df = append_order(_order, orders_df, ts)
            if not dry_run:
                place_order(_order, tag=tag)
                
    return orders_df

# %%
#conn = psycopg2.connect(database="predictit", host="localhost", port="5432")
#conn = create_engine("postgresql+psycopg2://@localhost:5432/predictit"
db_string = "postgresql+psycopg2://@localhost:5432/predictit"
def current_alloc(market_id, contract_id, tag=None):
    contract_orders = psql.read_sql("SELECT * from orders WHERE market_id = \'{m_id}\' AND contract_id = \'{c_id}\' AND tag = \'{tag}\'".format(m_id=market_id, c_id=contract_id, tag=tag), db_string)

    quantity = 0
    for i,o in contract_orders.iterrows():
        multiplier = -1 if o["action"] == "sell" else 1
        quantity += o["quantity"] * multiplier
    return quantity

def place_order(order, verbose=False, dry_run=True, tag=None):
    order["tag"] = tag
    df = pd.Series(order).to_frame().transpose()
    if not dry_run:
        df.to_sql('orders', con=db_string, if_exists='append', index=False)
    if verbose:
        print(order)
        
def record_timepoint(market_id=5458):
    new_data = False
    last_row = psql.read_sql("SELECT * from market_data WHERE market_id = \'{m_id}\' ORDER BY timestamp DESC LIMIT 1".format(m_id=market_id), db_string).iloc[0]
    last_ts = last_row["timestamp"]

    while new_data is False:
        data = fetch_market_data(market_id)
        print(data["timeStamp"],last_ts)
        if data["timeStamp"] > last_ts:
            new_data = True
        else:
            print("Retrying in one second...")
            time.sleep(1)

    data = fetch_market_data(market_id)
    twitter_handle = re.match(r".*@(\w{1,15})",data["shortName"]).group(0).split(' ')[-1]
    df = pd.Series({ "timestamp": data["timeStamp"], "market_id": data["id"], "handle": twitter_handle, "data": json.dumps(data) }).to_frame().transpose()
    df.to_sql('market_data', con=db_string, if_exists='append', index=False)

# %%
# bought_at: .10
# EV: .70
# price: .75
# SELL (not in optimal set)

# bought_at: .10
# EV: .70
# price: .50
# BUY (but would have more shares than recommended)

# bought_at: .10 
# EV: .70
# price: .05
# BUY (difference over current alloc)

# bought_at: .90
# EV: .70
# price: .75
# SELL (not in optimal set)

# bought_at: .90
# EV: .70
# price: .50
# BUY (likely allocation is less than what you have, in which case you sell)

# bought_at: .90
# EV: -.10
# price: .50
#

#market = { 
#    "id": 5411, 
#    "twitter_handle": "@potus", 
#    "contract_map": [ ("15008", range(0, 35)), ("15010",range(35, 40)), ("15011", range(40, 45)), ("15012", range(45, 50)), ("15013",range(50, 55)), ("15009", range(55, 60)), ("15014",range(60, 200))]
#}
df = pd.DataFrame({ "price_per_share": [.2, .51, .40, .01, .10], "proba": [.30, .10, .60, .02, .7] }, index=["0-59", "60-64", "65-69", "70-71", "test"])
df = pd.DataFrame({ "price_per_share": [.10, .2, .40], "proba": [.3, .30, .60] }, index=["1", "2", "3"])
alloc = kelly_criterion(df)
alloc
# Out:
#    beta  expected_revenue_rate  price_per_share  proba  pct_alloc
# 1   0.1                   2.70              0.1    0.3        0.4
# 2   0.2                   1.35              0.2    0.3        0.5
# 3   0.4                   1.35              0.4    0.6        1.0

# %%
eval_live_markets(show_market_research=False)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
# @vp tweets noon 5/10 - noon 5/17?
# Days left: 2.9526525125231484
# Number of tweets: 12
#
# Category probabilities:
# 0-39      0.361111
# 50-54     0.138889
# 45-49     0.152778
# 40-44     0.111111
# 55-59     0.125000
# 65-119    0.069444
# 60-64     0.041667
# dtype: float64
#
# Optimal allocation:
#       beta  expected_revenue_rate  price_per_share     proba  pct_alloc
# 0-39  0.23               1.413043             0.23  0.361111   0.141791
#
# New Orders:
#                                  action category type price_per_share  \
# timestamp
# 2019-05-13 10:51:49.177082-04:00    buy     0-39  yes            0.23
#
#                                  quantity market_id contract_id
# timestamp
# 2019-05-13 10:51:49.177082-04:00        4      5505       15496
# ----------------------------------------
#
#
# @potus tweets noon 5/10 - noon 5/17?
# Days left: 2.952660155150463
# Number of tweets: 38
#
# Category probabilities:
# 80-199    0.433962
# 75-79     0.169811
# 70-74     0.150943
# 65-69     0.150943
# 0-54      0.018868
# 55-59     0.075472
# 60-64     0.000000
# dtype: float64
#
# Optimal allocation:
#        beta  expected_revenue_rate  price_per_share     proba  pct_alloc
# 55-59  0.01               6.792453             0.01  0.075472   0.068583
# 65-69  0.03               4.528302             0.03  0.150943   0.130279
# 70-74  0.07               1.940701             0.07  0.150943   0.102725
# 75-79  0.14               1.091644             0.14  0.169811   0.073375
# 0-54   0.02               0.849057             0.02  0.018868   0.005091
#
# New Orders:
#                                  action category type price_per_share  \
# 2019-05-13 10:51:49.837405-04:00    buy    75-79  yes            0.14
# 2019-05-13 10:51:49.837405-04:00    buy    70-74  yes            0.07
# 2019-05-13 10:51:49.837405-04:00    buy    65-69  yes            0.03
# 2019-05-13 10:51:49.837405-04:00    buy     0-54  yes            0.02
# 2019-05-13 10:51:49.837405-04:00    buy    55-59  yes            0.01
#
#                                  quantity market_id contract_id
# 2019-05-13 10:51:49.837405-04:00        3      5504       15493
# 2019-05-13 10:51:49.837405-04:00        9      5504       15494
# 2019-05-13 10:51:49.837405-04:00       25      5504       15492
# 2019-05-13 10:51:49.837405-04:00        1      5504       15489
# 2019-05-13 10:51:49.837405-04:00       40      5504       15490
# ----------------------------------------
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':

# %%
FLUSH_AFTER = 500

def simulate_market(market, tag=None):
    historical_data = psql.read_sql("SELECT * from market_data WHERE handle = \'{handle}\' AND market_id = \'{m_id}\'".format(handle=market["twitter_handle"], m_id=market["id"]), db_string)
    path = "data/tweets/{handle}.csv".format(handle=market["twitter_handle"])
    
    outpath = "data/simulations/{handle}/{m_id}/{tag}".format(handle=market["twitter_handle"], m_id=market["id"], tag=tag)
    if not os.path.isdir(outpath):
        os.makedirs(outpath, exist_ok=True)
       
    update_twitter_history(market["twitter_handle"])
    df = get_historical_twitter_data(path)
    
    price_df = pd.DataFrame()
    proba_df = pd.DataFrame()
    order_df = pd.DataFrame()
    portfolio_df = pd.DataFrame()

    cash = 100;
    positions = {}
    
    iterations = 0;
    for i, data_point in historical_data.iterrows():
        timezone = pytz.timezone("US/Eastern")
        ts = timezone.localize( parser.parse(data_point["timestamp"]) )
        market_data = json.loads(data_point["data"])
        start_date, end_date = time_boundaries(market_data, timezone)
                
        if df[df["created_at"] > ts].empty:
            print('WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.')
            print('Likely not an error since we update historical data at the beginning of this function.')
        matching_tweets = df[(df["created_at"] >= start_date) & (df["created_at"] <= ts)]
        n_matching_tweets = len(matching_tweets)
        
        evaluation = eval_twitter_market(market, path, data=market_data, ts=ts, n_matching_tweets=n_matching_tweets, show_market_research=False, dry_run=True, tag=tag, positions=positions)

        _prices = {}
        for c in market_data["contracts"]:
            annotations = market["contract_map"][str(c["id"])]
            category = to_range_str(annotations["range"])
            _prices[category] = c["bestBuyYesCost"] 
        prices = pd.Series(_prices)
        prices.name = market_data["timeStamp"]
        price_df = price_df.append(prices)
        if len(price_df) == 1:
            price_df.index.name = "timestamp"
            
        proba = evaluation["category_probabilities"]
        proba.name = market_data["timeStamp"]
        proba_df = proba_df.append(proba)
        if len(proba_df) == 1:
            proba_df.index.name = "timestamp"
        
        new_orders = evaluation["orders"]
        contracts = market_data["contracts"]
        for i, o in new_orders.iterrows():
            order_price = o["quantity"] * o["price_per_share"]
            if o["action"] == "buy":
                cash -= order_price
                if o["contract_id"] in positions:
                    q, p = positions[o["contract_id"]]
                    positions[o["contract_id"]] = (q + o["quantity"], p + order_price)
                else:
                    positions[o["contract_id"]] = (o["quantity"], order_price)
            else:
                q, p = positions[o["contract_id"]]
                avg_price = p/q
                gain = True if o["price_per_share"] > avg_price else False
                tax = 0
                if gain:
                    winnings = (o["price_per_share"] * o["quantity"]) - (avg_price * o["quantity"])
                    tax = winnings * TAX_RATE
                cash += order_price - tax
                positions[o["contract_id"]] = (q - o["quantity"], p - order_price)
        
        #print("NEW ORDERS",new_orders)
        #print("CASH",cash)
        investment = 0
        for c in contracts:
            if c["id"] in positions:
                quantity = positions[c["id"]][0]
                current_price = c["bestBuyYesCost"] if c["bestBuyYesCost"] else 0
                investment += current_price * quantity
        
        #print("INVESTMENT", investment)
        order_df = pd.concat([order_df, evaluation["orders"]])
        
        p_row = pd.Series({ "cash": cash, "investment": investment, "value": cash + investment })
        p_row.name = market_data["timeStamp"]
        portfolio_df = portfolio_df.append(p_row)
        if len(portfolio_df) == 1:
            portfolio_df.index.name = "timestamp"

        if iterations > 0 and iterations % FLUSH_AFTER == 0:
            append = True if iterations > FLUSH_AFTER else False
            write_header = not append
            mode = 'a' if append else 'w'
            
            proba_df.to_csv(outpath + "/proba.csv", mode=mode, header=write_header)
            price_df.to_csv(outpath + "/prices.csv", mode=mode, header=write_header)
            order_df.to_csv(outpath + "/orders.csv", mode=mode, header=write_header)
            portfolio_df.to_csv(outpath + "/portfolio.csv", mode=mode, header=write_header)

            price_df = pd.DataFrame()
            proba_df = pd.DataFrame()
            order_df = pd.DataFrame()
            portfolio_df = pd.DataFrame()
            
        iterations = iterations + 1
            
def get_historical_twitter_data(path):
    df = pd.read_csv(path)
    df["created_at"] = pd.to_datetime(df["created_at"])
    df["created_at"] = df["created_at"].dt.tz_localize('UTC').dt.tz_convert('US/Eastern')
    return df

def simulate_markets(tag=None):
    for m in markets:
        simulate_market(m, tag=tag)

# %%
tag = datetime.datetime.now().strftime('%Y%m-%d%H-%M%S') + "-baseline"
simulate_market(markets[0], tag=tag)
# Out:
# 7
# 0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# ...
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.

# %%
tag = datetime.datetime.now().strftime('%Y%m-%d%H-%M%S') + "-baseline"
simulate_market(markets[1], tag=tag)
# Out:
# 1
# 0
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.
# WARNING: Historical tweets do not contain tweets greater than the point in time being evaluated.
# Likely not an error since we update historical data at the beginning of this function.

# %%
fetch_market_data(5504)
# Out:
# {'id': 5504,
#  'name': 'How many tweets will @potus post from noon 5/10 - noon 5/17?',
#  'shortName': '@potus tweets noon 5/10 - noon 5/17?',
#  'image': 'https://az620379.vo.msecnd.net/images/Markets/a5210b54-8c02-4b28-9362-ef84b9b14c91.png',
#  'url': 'https://www.predictit.org/markets/detail/5504/How-many-tweets-will-@potus-post-from-noon-5-10-noon-5-17',
#  'contracts': [{'id': 15495,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_b7d571df-c1dd-4e2c-bac4-9c912f6d02a2.png',
#    'name': '80 or more',
#    'longName': 'Will @potus post 80 or more tweets from noon 5/10 - noon 5/17?',
#    'shortName': '80+',
#    'status': 'Open',
#    'lastTradePrice': 0.83,
#    'bestBuyYesCost': 0.83,
#    'bestBuyNoCost': 0.2,
#    'bestSellYesCost': 0.8,
#    'bestSellNoCost': 0.17,
#    'lastClosePrice': 0.63,
#    'displayOrder': 0},
#   {'id': 15493,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_0407824b-357e-48ef-99ab-2cfa47e32c92.png',
#    'name': '75 - 79',
#    'longName': 'Will @potus post 75 - 79 tweets from noon 5/10 - noon 5/17?',
#    'shortName': '75 - 79',
#    'status': 'Open',
#    'lastTradePrice': 0.13,
#    'bestBuyYesCost': 0.14,
#    'bestBuyNoCost': 0.9,
#    'bestSellYesCost': 0.1,
#    'bestSellNoCost': 0.86,
#    'lastClosePrice': 0.17,
#    'displayOrder': 0},
#   {'id': 15494,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_f1102ef7-68d0-463b-a8d2-8b708a149916.png',
#    'name': '70 - 74',
#    'longName': 'Will @potus post 70 - 74 tweets from noon 5/10 - noon 5/17?',
#    'shortName': '70 - 74',
#    'status': 'Open',
#    'lastTradePrice': 0.05,
#    'bestBuyYesCost': 0.07,
#    'bestBuyNoCost': 0.95,
#    'bestSellYesCost': 0.05,
#    'bestSellNoCost': 0.93,
#    'lastClosePrice': 0.13,
#    'displayOrder': 0},
#   {'id': 15492,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_6e5747e0-e039-4791-8a7d-f596591a7c9e.png',
#    'name': '65 - 69',
#    'longName': 'Will @potus post 65 - 69 tweets from noon 5/10 - noon 5/17?',
#    'shortName': '65 - 69',
#    'status': 'Open',
#    'lastTradePrice': 0.02,
#    'bestBuyYesCost': 0.03,
#    'bestBuyNoCost': 0.98,
#    'bestSellYesCost': 0.02,
#    'bestSellNoCost': 0.97,
#    'lastClosePrice': 0.08,
#    'displayOrder': 0},
#   {'id': 15489,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_f57a443e-f48b-4db2-a8dc-bbde6bd509dd.png',
#    'name': '54 or fewer',
#    'longName': 'Will @potus post 54 or fewer tweets from noon 5/10 - noon 5/17?',
#    'shortName': '54-',
#    'status': 'Open',
#    'lastTradePrice': 0.01,
#    'bestBuyYesCost': 0.02,
#    'bestBuyNoCost': 0.99,
#    'bestSellYesCost': 0.01,
#    'bestSellNoCost': 0.98,
#    'lastClosePrice': 0.02,
#    'displayOrder': 0},
#   {'id': 15490,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_c1e5ff90-22c5-4bae-9331-6a7a5959b834.png',
#    'name': '55 - 59',
#    'longName': 'Will @potus post 55 - 59 tweets from noon 5/10 - noon 5/17?',
#    'shortName': '55 - 59',
#    'status': 'Open',
#    'lastTradePrice': 0.01,
#    'bestBuyYesCost': 0.01,
#    'bestBuyNoCost': None,
#    'bestSellYesCost': None,
#    'bestSellNoCost': 0.99,
#    'lastClosePrice': 0.03,
#    'displayOrder': 0},
#   {'id': 15491,
#    'dateEnd': '2019-05-17T12:00:00',
#    'image': 'https://az620379.vo.msecnd.net/images/Contracts/small_079d96c8-160d-49d9-9182-91bda70d29a7.png',
#    'name': '60 - 64',
#    'longName': 'Will @potus post 60 - 64 tweets from noon 5/10 - noon 5/17?',
#    'shortName': '60 - 64',
#    'status': 'Open',
#    'lastTradePrice': 0.01,
#    'bestBuyYesCost': 0.02,
#    'bestBuyNoCost': 0.99,
#    'bestSellYesCost': 0.01,
#    'bestSellNoCost': 0.98,
#    'lastClosePrice': 0.06,
#    'displayOrder': 0}],
#  'timeStamp': '2019-05-13T10:47:55.7883203',
#  'status': 'Open'}

# %%
def graph_simulation(twitter_handle, market_id):
    root_path = "data/simulations/{handle}/{m_id}".format(handle=twitter_handle, m_id=market_id)

    for d in next(os.walk(root_path))[1]:
        dir_path = root_path + '/' + d
        print(dir_path)
        
        # market price vs predicted value
        prices = pd.read_csv(dir_path + "/prices.csv")
        prices["timestamp"] = pd.to_datetime(prices['timestamp']).dt.tz_localize('US/Eastern')
        prices = prices.set_index("timestamp")
        proba = pd.read_csv(dir_path + "/proba.csv")
        proba["timestamp"] = pd.to_datetime(proba['timestamp']).dt.tz_localize('US/Eastern')
        proba = proba.set_index("timestamp")
        sorted_ts = proba.sort_values('timestamp')
    
        timezone = pytz.timezone("US/Eastern")
        start_date = sorted_ts.index[0]
        end_date = sorted_ts.index[len(sorted_ts)-1]
        
        _tweets = get_historical_twitter_data("data/tweets/{handle}.csv".format(handle=twitter_handle))
        tweets = _tweets[(_tweets["created_at"] >= start_date) & (_tweets["created_at"] <= end_date)]


        cmap = cm.get_cmap('Dark2',len(proba.columns))
        colors = cmap(np.linspace(0, 1, len(proba.columns)))
    
        ax1 = prices.plot(linestyle="-",color=colors,figsize=(25,15), use_index=True)
        ax2 = proba.plot(linestyle="--", ax=ax1,color=colors, use_index=True)
    
        for i, t in tweets.iterrows():
            ax1.axvline(x=t["created_at"], color="red", linewidth=.5)
        plt.show()

        # portfolio value
        portfolio = pd.read_csv(dir_path + "/portfolio.csv")
        portfolio["timestamp"] = pd.to_datetime(portfolio['timestamp']).dt.tz_localize('US/Eastern')
        portfolio = portfolio.set_index("timestamp")
        sorted_ts = portfolio.sort_values('timestamp')
        
        ax = portfolio.value.plot(linestyle="-",color=colors,figsize=(25,15), use_index=True)
        plt.show()

# %%
graph_simulation("@vp", 5478)
# Out:
# data/simulations/@vp/5478/continuous-interpolation-201905-1110-0803-
# data/simulations/@vp/5478/201905-1112-2022-baseline_new_calc
# data/simulations/@vp/5478/baseline

# %%
graph_simulation("@potus", 5504)
# Out:
# data/simulations/@potus/5504/201905-1311-0948-baseline

# %% [markdown]
# TODO:
# 1. bump account allocation (variable based on number of markets played?)
# 2. adjust account allocation based on ???
# 3. bucketing starting at noon
# 4. iterpolate probabilities between time n and n+1
# 5. predicting market movement to get better prices
# 6. sell at sell price in simulation, not buy price
# 7. overnight - beat the linear interpolation models
# 8. smoothing the probability distributions

# %%
def exclude_rows(group, time_elapsed):
    group_start = group.name
    ts = group_start + time_elapsed
    return group[(group["created_at"] >= ts) & (group["id"].notnull())]

def historical_tweet_counts(df, start_date, time_elapsed):
    min_date = df["created_at"].min()
    historical_start_date = next_weekday_matching_time(min_date, start_date)
    df = pd.concat([df, pd.DataFrame({ "created_at": [historical_start_date] })])
    df = df[df["created_at"] >= historical_start_date]
    grouped = df.groupby(pd.Grouper(key='created_at', freq='7D', axis=0))
    time_elapsed_adjusted = grouped.apply(lambda g: exclude_rows(g, time_elapsed)).count(level="created_at")["id"]
    return time_elapsed_adjusted.drop(time_elapsed_adjusted.tail(1).index) # drop last row in case its a count over less than the full time bucket

start_date = tz.localize(datetime.datetime(2019,5,3,12,0,0))
time_elapsed = datetime.timedelta(1, 43200)

df = pd.read_csv("data/tweets/@vp.csv")
df['created_at'] = pd.to_datetime(df["created_at"]).dt.tz_localize('UTC').dt.tz_convert('US/Eastern')
x=historical_tweet_counts(df, start_date, time_elapsed)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e90377174688> in <module>()
#      13     return time_elapsed_adjusted.drop(time_elapsed_adjusted.tail(1).index) # drop last row in case its a count over less than the full time bucket
#      14
# ---> 15 start_date = tz.localize(datetime.datetime(2019,5,3,12,0,0))
#      16 time_elapsed = datetime.timedelta(1, 43200)
#      17
#
# NameError: name 'tz' is not defined

# %%
for name, group in grouped:
     print("Group: ", name)
     print("-" * 27)
     print(group, end="\n\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9080a1298127> in <module>()
# ----> 1 for name, group in grouped:
#       2      print("Group: ", name)
#       3      print("-" * 27)
#       4      print(group, end="\n\n")
#
# NameError: name 'grouped' is not defined

# %%
directory = "data/simulations/{h}/{m_id}/".format(h="@vp",m_id=5478)
next(os.walk(directory))[1]
# Out:
# ['continuous-interpolation-201905-1110-0803-', 'baseline']

# %%
show_twitter_market_research("data/tweets/@vp.csv")
# Out:
# 2017-12-22 16:44:32-05:00 2019-05-03 12:00:00-04:00 2017-12-20 16:44:32-05:00
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
# 43

# %%
df = pd.read_csv("data/tweets/@vp.csv")
df["created_at"] = pd.to_datetime(df['created_at']).dt.tz_localize('UTC').dt.tz_convert('US/Eastern')

# %%
# number of tweets per week
df
#bucketed(df, start_on="Thursday")
#b.plot(title="Tweets per Week")
#plt.show()
# Out:
#                     created_at                   id  \
# 0    2019-05-11 09:56:56-04:00  1127210988070166534
# 1    2019-05-11 09:40:56-04:00  1127206962083577856
# 2    2019-05-10 21:40:10-04:00  1127025572331360262
# 3    2019-05-10 15:30:09-04:00  1126932454751784962
# 4    2019-05-10 14:33:03-04:00  1126918086181949441
# 5    2019-05-10 10:03:26-04:00  1126850235400060929
# 6    2019-05-10 09:38:24-04:00  1126843935031267330
# 7    2019-05-10 07:04:59-04:00  1126805325162647553
# 8    2019-05-09 20:09:00-04:00  1126640241731952640
# 9    2019-05-09 19:43:06-04:00  1126633724886564864
# 10   2019-05-09 19:18:32-04:00  1126627541714862080
# 11   2019-05-09 19:05:48-04:00  1126624336541093888
# 12   2019-05-09 18:32:00-04:00  1126615831792762881
# 13   2019-05-09 18:27:23-04:00  1126614670515765248
# 14   2019-05-09 16:26:38-04:00  1126584283185983488
# 15   2019-05-09 16:14:02-04:00  1126581111679852544
# 16   2019-05-09 16:11:14-04:00  1126580406889996289
# 17   2019-05-09 16:10:04-04:00  1126580114135879687
# 18   2019-05-09 15:33:02-04:00  1126570794241409025
# 19   2019-05-09 15:28:45-04:00  1126569714266902529
# 20   2019-05-09 14:27:08-04:00  1126554209091035138
# 21   2019-05-09 10:36:21-04:00  1126496132220248065
# 22   2019-05-09 10:03:23-04:00  1126487833710145536
# 23   2019-05-09 09:22:39-04:00  1126477581522493440
# 24   2019-05-08 20:05:31-04:00  1126276978594725888
# 25   2019-05-08 20:04:50-04:00  1126276805361635328
# 26   2019-05-08 20:04:14-04:00  1126276655725596672
# 27   2019-05-08 18:11:04-04:00  1126248174807445504
# 28   2019-05-08 16:48:18-04:00  1126227345042485250
# 29   2019-05-08 15:12:20-04:00  1126203197016694786
# ...                        ...                  ...
# 2019-01-18   30.0
# 2019-01-25   27.0
# 2019-02-01   60.0
# 2019-02-08   38.0
# 2019-02-15   32.0
# 2019-02-22   38.0
# 2019-03-01   39.0
# 2019-03-08   44.0
# 2019-03-15   28.0
# 2019-03-22   44.0
# 2019-03-29   42.0
# 2019-04-05   39.0
# 2019-04-12   35.0
# 2019-04-19   23.0
# 2019-04-26   56.0
# 2019-05-03   61.0
#
# [72 rows x 1 columns]

# %%
tz = pytz.timezone("US/Eastern")
start_date = tz.localize(datetime.datetime(2019,5,3,12,0,0))
c = historical_tweet_counts(df, start_date, datetime.timedelta(0))
c.size
#c.plot(title="New Tweets per Week")
#plt.show()
# Out:
# 2017-12-22 16:44:32-05:00 2019-05-03 12:00:00-04:00 2017-12-20 16:44:32-05:00
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   if __name__ == '__main__':
# 72

# %%
tz = pytz.timezone("US/Eastern")
start_date = tz.localize(datetime.datetime(2019,5,3,12,0,0))
ts = tz.localize(datetime.datetime(2019,5,3,13,0,0))

# %%
ts - start_date
# Out:
# datetime.timedelta(0, 3600)

# %%
pd.read_csv("data/simulations/@vp/5478/201905-1112-2022-baseline_new_calc/orders.csv")
# Out:
#                            Unnamed: 0 action category type  price_per_share  \
# 0    2019-05-03 14:37:02.565366-04:00    buy    55-99  yes             0.27
# 1    2019-05-03 14:37:02.565366-04:00    buy    35-39  yes             0.14
# 2    2019-05-03 14:37:02.565366-04:00    buy     0-29  yes             0.06
# 3    2019-05-03 14:39:02.616948-04:00   sell    55-99  yes             0.33
# 4    2019-05-03 14:39:02.616948-04:00   sell    35-39  yes             0.14
# 5    2019-05-03 14:39:02.616948-04:00   sell     0-29  yes             0.06
# 6    2019-05-03 14:47:02.699061-04:00    buy    55-99  yes             0.29
# 7    2019-05-03 14:55:02.513930-04:00    buy    55-99  yes             0.27
# 8    2019-05-03 14:55:02.513930-04:00    buy    35-39  yes             0.14
# 9    2019-05-03 14:55:02.513930-04:00    buy     0-29  yes             0.06
# 10   2019-05-03 15:24:03.279962-04:00   sell    55-99  yes             0.29
# 11   2019-05-03 15:24:03.279962-04:00   sell    35-39  yes             0.14
# 12   2019-05-03 16:15:02.623537-04:00    buy    55-99  yes             0.29
# 13   2019-05-03 16:15:02.623537-04:00    buy    35-39  yes             0.14
# 14   2019-05-03 16:15:02.623537-04:00    buy    30-34  yes             0.07
# 15   2019-05-03 16:15:02.623537-04:00    buy     0-29  yes             0.06
# 16   2019-05-03 16:17:02.628632-04:00   sell    55-99  yes             0.35
# 17   2019-05-03 16:25:02.602559-04:00    buy    55-99  yes             0.31
# 18   2019-05-03 16:39:02.886759-04:00    buy    55-99  yes             0.30
# 19   2019-05-03 16:49:02.500720-04:00    buy    55-99  yes             0.30
# 20   2019-05-03 16:49:02.500720-04:00    buy    35-39  yes             0.12
# 21   2019-05-03 16:49:02.500720-04:00   sell    30-34  yes             0.08
# 22   2019-05-03 16:50:03.190169-04:00   sell    55-99  yes             0.34
# 23   2019-05-03 16:50:03.190169-04:00   sell    35-39  yes             0.12
